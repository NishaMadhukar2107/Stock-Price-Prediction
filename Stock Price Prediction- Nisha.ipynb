# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('NFLX.csv')

# %%
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200
# 7  10972000
# 8  10759700
# 9   8312400

# %%
df.tail(10)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 999   2022-01-24  383.910004  387.260010  351.459991  387.149994  387.149994
# 1000  2022-01-25  379.140015  387.709991  365.130005  366.420013  366.420013
# 1001  2022-01-26  378.269989  382.660004  356.619995  359.700012  359.700012
# 1002  2022-01-27  382.059998  394.799988  378.100006  386.700012  386.700012
# 1003  2022-01-28  386.760010  387.000000  372.079987  384.359985  384.359985
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 999   32346000
# 1000  15145800
# 1001  12684000
# 1002  24324700
# 1003  11966600
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400

# %% [markdown]
# ### Checking the shape of the dataset

# %%
df.shape
# Out:
# (1009, 7)

# %% [markdown]
# There are 1009 rows and 7 columns

# %% [markdown]
# ### Checking the categorical and numerical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %% [markdown]
# There are 6 numerical columns and 1 categorical columns

# %% [markdown]
# ### Descriptive Statistics - Numerical columns

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %% [markdown]
# ### Checking the null values

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# There are no null values.

# %%
df.set_index('Date',drop=True,inplace=True) 
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#               Volume
# Date
# 2018-02-05  11896100
# 2018-02-06  12595800
# 2018-02-07   8981500
# 2018-02-08   9306700
# 2018-02-09  16906900
# 2018-02-12   8534900
# 2018-02-13   6855200
# 2018-02-14  10972000
# 2018-02-15  10759700
# 2018-02-16   8312400

# %%
plt.figure(figsize = (15,30))
df.hist()
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>],
#        [<Axes: title={'center': 'Low'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'Adj Close'}>,
#         <Axes: title={'center': 'Volume'}>]], dtype=object)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\madhu\anaconda3\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: setuptools in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (65.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: packaging in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.3)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\madhu\anaconda3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\madhu\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\madhu\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\madhu\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\madhu\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\madhu\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\madhu\anaconda3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\madhu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\madhu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\madhu\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\madhu\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madhu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\madhu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madhu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\madhu\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\madhu\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\madhu\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\madhu\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\madhu\anaconda3\lib\site-packages (0.2.31)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: html5lib>=1.1 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: requests>=2.31 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\madhu\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\madhu\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\madhu\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\madhu\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\madhu\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\madhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\madhu\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping
import yfinance as yf

# %% [markdown]
# # EDA analysis

# %% [markdown]
# ### Plot closing prices over time

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x=df.index, y=df['Close'])
plt.title('Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.show()

# %% [markdown]
# ### Plot daily returns

# %%
df['Daily_Return'] = df['Close'].pct_change()
plt.figure(figsize=(12, 6))
sns.lineplot(x=df.index, y=df['Daily_Return'])
plt.title('Daily Returns Over Time')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.show()

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ### Create a column for the target variable (next day's closing price)

# %%
df['Next_Close'] = df['Close'].shift(-1)

# %% [markdown]
# ### Scaling the data

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
df[['Close', 'Next_Close']] = scaler.fit_transform(df[['Close', 'Next_Close']])

# %% [markdown]
# ### Create sequences for LSTM

# %%
def create_sequences(data, seq_length):
    sequences = []
    targets = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target = data[i+seq_length]
        sequences.append(seq)
        targets.append(target)
    return np.array(sequences), np.array(targets)

# %% [markdown]
# ### Set sequence length and split the data

# %%
sequence_length = 3
X, y = create_sequences(df[['Close', 'Next_Close']].values, sequence_length)

# %% [markdown]
# ### Splitting the data

# %%
train_size = int(len(X) * 0.80)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ### Define the LSTM model

# %%
model = Sequential()
model.add(LSTM(units=50, activation='relu', input_shape=(sequence_length, 2)))
model.add(Dense(units=2))
model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# #### Train the model

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1, callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 23/23 [==============================] - 2s 15ms/step - loss: 0.0982 - val_loss: 0.3130
# Epoch 2/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0522 - val_loss: 0.1567
# Epoch 3/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0169 - val_loss: 0.0315
# Epoch 4/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0127
# Epoch 5/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0046
# Epoch 6/50
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 7/50
# 23/23 [==============================] - 0s 7ms/step - loss: 7.6785e-04 - val_loss: 0.0016
# Epoch 8/50
# 23/23 [==============================] - 0s 6ms/step - loss: 6.9924e-04 - val_loss: 0.0015
# Epoch 9/50
# 23/23 [==============================] - 0s 6ms/step - loss: 6.5831e-04 - val_loss: 0.0012
# Epoch 10/50
# 23/23 [==============================] - 0s 5ms/step - loss: 6.2652e-04 - val_loss: 0.0012
# Epoch 11/50
# 23/23 [==============================] - 0s 5ms/step - loss: 6.2015e-04 - val_loss: 0.0012
# Epoch 12/50
# 23/23 [==============================] - 0s 4ms/step - loss: 6.2211e-04 - val_loss: 0.0012
# Epoch 13/50
# 23/23 [==============================] - 0s 4ms/step - loss: 6.1209e-04 - val_loss: 0.0012
# Epoch 14/50
# 23/23 [==============================] - 0s 5ms/step - loss: 6.0760e-04 - val_loss: 0.0012
# Epoch 15/50
# 23/23 [==============================] - 0s 5ms/step - loss: 6.1283e-04 - val_loss: 0.0012
# Epoch 16/50
# 23/23 [==============================] - 0s 5ms/step - loss: 6.0913e-04 - val_loss: 0.0012
# Epoch 17/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.9684e-04 - val_loss: 0.0012
# Epoch 18/50
# 23/23 [==============================] - 0s 4ms/step - loss: 6.0260e-04 - val_loss: 0.0012
# Epoch 19/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.9016e-04 - val_loss: 0.0012
# Epoch 20/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.8479e-04 - val_loss: 0.0012
# Epoch 21/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.8781e-04 - val_loss: 0.0012
# Epoch 22/50
# 23/23 [==============================] - 0s 4ms/step - loss: 5.8540e-04 - val_loss: 0.0012
# Epoch 23/50
# 23/23 [==============================] - 0s 4ms/step - loss: 6.0434e-04 - val_loss: 0.0012
# Epoch 24/50
# 23/23 [==============================] - 0s 4ms/step - loss: 5.7823e-04 - val_loss: 0.0012
# Epoch 25/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.7918e-04 - val_loss: 0.0012
# Epoch 26/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.6761e-04 - val_loss: 0.0012
# Epoch 27/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.7141e-04 - val_loss: 0.0011
# Epoch 28/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.5335e-04 - val_loss: 0.0011
# Epoch 29/50
# 23/23 [==============================] - 0s 4ms/step - loss: 5.6187e-04 - val_loss: 0.0011
# Epoch 30/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.4452e-04 - val_loss: 0.0011
# Epoch 31/50
# 23/23 [==============================] - 0s 4ms/step - loss: 5.3770e-04 - val_loss: 0.0011
# Epoch 32/50
# 23/23 [==============================] - 0s 4ms/step - loss: 5.3292e-04 - val_loss: 0.0011
# Epoch 33/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.3778e-04 - val_loss: 0.0011
# Epoch 34/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.1980e-04 - val_loss: 0.0010
# Epoch 35/50
# 23/23 [==============================] - 0s 6ms/step - loss: 5.1214e-04 - val_loss: 0.0010
# Epoch 36/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.0586e-04 - val_loss: 0.0010
# Epoch 37/50
# 23/23 [==============================] - 0s 5ms/step - loss: 5.1508e-04 - val_loss: 9.9998e-04
# Epoch 38/50
# 23/23 [==============================] - 0s 5ms/step - loss: 4.9058e-04 - val_loss: 9.9408e-04
# Epoch 39/50
# 23/23 [==============================] - 0s 6ms/step - loss: 4.9295e-04 - val_loss: 0.0010
# Epoch 40/50
# 23/23 [==============================] - 0s 5ms/step - loss: 4.8137e-04 - val_loss: 0.0010
# Epoch 41/50
# 23/23 [==============================] - 0s 5ms/step - loss: 4.7358e-04 - val_loss: 9.3793e-04
# Epoch 42/50
# 23/23 [==============================] - 0s 5ms/step - loss: 4.6194e-04 - val_loss: 9.3057e-04
# Epoch 43/50
# 23/23 [==============================] - 0s 4ms/step - loss: 4.5983e-04 - val_loss: 9.8355e-04
# Epoch 44/50
# 23/23 [==============================] - 0s 4ms/step - loss: 4.6015e-04 - val_loss: 9.0014e-04
# Epoch 45/50
# 23/23 [==============================] - 0s 4ms/step - loss: 4.4578e-04 - val_loss: 9.0118e-04
# Epoch 46/50
# 23/23 [==============================] - 0s 4ms/step - loss: 4.4222e-04 - val_loss: 8.8978e-04
# Epoch 47/50
# 23/23 [==============================] - 0s 4ms/step - loss: 4.2569e-04 - val_loss: 8.7888e-04
# Epoch 48/50
# 23/23 [==============================] - 0s 4ms/step - loss: 4.2766e-04 - val_loss: 8.4485e-04
# Epoch 49/50
# 23/23 [==============================] - 0s 6ms/step - loss: 4.3198e-04 - val_loss: 8.2834e-04
# Epoch 50/50
# 23/23 [==============================] - 0s 5ms/step - loss: 4.0680e-04 - val_loss: 8.1023e-04

# %% [markdown]
# # Predictions of the model

# %%
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 26/26 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 4ms/step

# %% [markdown]
# ### Inverse transform the predictions to original state

# %%
train_predictions_inv = scaler.inverse_transform(train_predictions)
test_predictions_inv = scaler.inverse_transform(test_predictions)
y_train_inv = scaler.inverse_transform(y_train)
y_test_inv = scaler.inverse_transform(y_test)

# %%
df.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Next_Close      1
# Daily_Return    1
# dtype: int64

# %%
df['Next_Close'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Treating the null values

# %%
df['Next_Close'].fillna(df['Next_Close'].mean(), inplace=True)

# %%
df['Daily_Return'].fillna(df['Daily_Return'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Next_Close      0
# Daily_Return    0
# dtype: int64

# %% [markdown]
# # Calculate RMSE

# %%
print("NaN values in y_train_inv:", np.isnan(y_train_inv).any())
print("NaN values in y_test_inv:", np.isnan(y_test_inv).any())
# Out:
# NaN values in y_train_inv: False
# NaN values in y_test_inv: True

# %%
from numpy import nan_to_num

# Replace NaN values with a specific number, for example, 0
y_test_inv = nan_to_num(y_test_inv, nan=0)
test_predictions_inv = nan_to_num(test_predictions_inv, nan=0)

# Now compute the RMSE
test_rmse = np.sqrt(mean_squared_error(y_test_inv, test_predictions_inv))

# %%
train_rmse = np.sqrt(mean_squared_error(y_train_inv, train_predictions_inv))

# %% [markdown]
# ### Plot the results

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index[:len(y_train_inv)], y_train_inv[:, 0], label='Actual Train Prices', color='blue')
plt.plot(df.index[len(y_train_inv):len(y_train_inv)+len(y_test_inv)], y_test_inv[:, 0], label='Actual Test Prices', color='green')
plt.plot(df.index[:len(train_predictions_inv)], train_predictions_inv[:, 0], label='Predicted Train Prices', linestyle='--', color='red')
plt.plot(df.index[len(y_train_inv):len(y_train_inv)+len(test_predictions_inv)], test_predictions_inv[:, 0], label='Predicted Test Prices', linestyle='--', color='orange')
plt.title('Stock Price Prediction using LSTM')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Print the evaluation results
print(f'Train RMSE: {train_rmse:.2f}')
print(f'Test RMSE: {test_rmse:.2f}')
# Out:
# Train RMSE: 9.63
# Test RMSE: 25.25

# %% [markdown]
# This indicates that a lower RMSE represents better model performance.
